# %%
from config_gui import launch_gui
launch_gui()
# Out:
# ...
# パイプライン実行開始
# ...
# //Nagoya_AMCBNAS2/wakelab7/okita/whisker_analysis/20260114-1_Wildtype_S1BF/260114-4_Wildtype_S1BF_920_wisker/260114-4_Wildtype_S1BF_920_wisker.plx を解析します。
# === パイプライン開始: 260114-4_Wildtype_S1BF_920_wisker ===
#
# [1/6] データ読み込み...
# ...
# Parsing signal channels: 100%|██████████| 128/128 [00:00<00:00, 32000.41it/s]
# Parsing spike channels: 16it [00:00, 8002.49it/s]
# Parsing event channels: 100%|██████████| 43/43 [00:00<?, ?it/s]
#   LFP: (112460, 16), fs=1000Hz
#   フレーム同期: EVT03, 1241個
#   Trim範囲: 7.71s ~ 106.89s
# PLX全長: 112.5秒
# 動画フレーム数: 1241
# 同期イベント数: 1241
# Trim範囲: 7.7〜106.9秒 (= 99.2秒)
#
# [2/6] フィルタリング...
#   バンドパス: 0.1-100.0Hz (order=4)
#   ノッチフィルタ: 60.0Hz (Q=60.0)
#   Trim: 7.7〜106.9秒 (99.2秒間)
#   → FFT比較プロット出力
#
# [2.6/6] 高調波ノイズ除去（ピエゾ由来）...
#   高調波ノイズ除去: [10.0, 30.0, 50.0, 70.0] Hz
#   基本周波数: 10.0Hz（矩形波）
#   除去対象: ['10Hz', '30Hz', '50Hz', '70Hz']（奇数倍高調波）
#   ノッチQ値: 220.0（帯域幅 ≈ 0.05Hz）
#   --- 神経信号帯域への影響 ---
#     theta  ( 4- 8Hz): -0.0% ✓
# ...
